# %%
import sys # biblioteka systemowa
import numpy as np
import random # liczby losowe
sys.path.append('Users\stiop\Algorytmy ewolucyjne')

# %%
from Algorithms import * # Algorithms jest nazwą podkatalogu w powyższej ścieżce (pakiet), zawierającego moduły
# Out:
# Invoking __init__.py for Algorithms

# %%
help(Algorithms)
# Out:
# Help on package Algorithms:
#
# NAME
#     Algorithms - # coding: utf-8
#
# PACKAGE CONTENTS
#     AntColonyOptimization
#     GeneticAlgorithm
#     bruteForce
#     genetic
#     nearestNeighbors
#     opt2_Algorithm
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\__init__.py

# %%
help(genetic)
# Out:
# Help on module Algorithms.genetic in Algorithms:
#
# NAME
#     Algorithms.genetic - # coding: utf-8
#
# FUNCTIONS
#     GENETIC()
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\genetic.py

# %%
help(bruteForce)
# Out:
# Help on module Algorithms.bruteForce in Algorithms:
#
# NAME
#     Algorithms.bruteForce
#
# DESCRIPTION
#     Brutalna siła (Brute force, BF) - sprawdzenie wszystkich możliwości
#     Inne nazwy: przegląd zupełny, metoda siłowa.
#
#     Użytkownik sam podaje ilość miast n, a także listę ich współrzędnych cities.
#
# FUNCTIONS
#     bf(n, cities)
#
# DATA
#     __warningregistry__ = {'version': 19}
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\bruteforce.py

# %%
help(nearestNeighbors)
# Out:
# Help on module Algorithms.nearestNeighbors in Algorithms:
#
# NAME
#     Algorithms.nearestNeighbors
#
# DESCRIPTION
#     Algorytm najbliższego sąsiada (zachłanny)
#     Algorytm zachłanny (greedy algorthm) optymalizuje efekt w najbliższym kroku, ale nie myśli o dalszej przyszłości!
#
#     Użytkownik sam podaje ilość miast - n, a także listę ich współrzędnych - cities .
#
# FUNCTIONS
#     greedy_algorthm(n, cities)
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\nearestneighbors.py

# %%
help(AntColonyOptimization)
# Out:
# Help on module Algorithms.AntColonyOptimization in Algorithms:
#
# NAME
#     Algorithms.AntColonyOptimization - Algorytm mrówkowy - Ant Colony Optimization, ACO.
#
# DESCRIPTION
#     Mrówka, niosąc pokarm z F do mrowiska (gniazda) N, zostawia na ścieżce feromon.
#     Kolejne mrówki wybierają preferencyjnie tę drogę, gdzie jest najwięcej feromonu.
#     Po pewnym czasie zostaje znaleziona optymalna trasa!
#
#     Użytkownik sam podaje ilość miast - n, a także listę ich współrzędnych - cities .
#
# FUNCTIONS
#     aco(n, cities)
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\antcolonyoptimization.py

# %%
help(GeneticAlgorithm)
# Out:
# Help on module Algorithms.GeneticAlgorithm in Algorithms:
#
# NAME
#     Algorithms.GeneticAlgorithm - Algorytm Genetyczny -  Genetic Algorithm, GA.
#
# DESCRIPTION
#     GA jest jedną z ewolucyjnych metod optymalizacji. Zalicza się go do klasy algorytmów heurystycznych.
#     Przeszukiwanie możliwych rozwiązań w celu znalezienia rozwiązania najlepszego lub potencjalnie
#     najlepszego odbywa się za pomocą mechanizmów ewolucji oraz doboru naturalnego.
#
# FUNCTIONS
#     GA(n, npop, start, cities)
#
# FILE
#     c:\users\stiop\algorytmy ewolucyjne\library_of_algorithms\algorithms\geneticalgorithm.py

# %%
n=40

# %%
cities=np.array([[random.random(),random.random()] for n in range(n)]) # lista współrzędnych miast
cities
# Out:
# array([[0.83352968, 0.87646696],
#        [0.12750918, 0.44639619],
#        [0.94926734, 0.38624461],
#        [0.85833731, 0.66848989],
#        [0.25747728, 0.62044767],
#        [0.3903354 , 0.57340185],
#        [0.69640149, 0.96130454],
#        [0.3461861 , 0.00865295],
#        [0.52281728, 0.1005004 ],
#        [0.68189452, 0.2260178 ],
#        [0.625873  , 0.89234985],
#        [0.85016115, 0.48564692],
#        [0.73992009, 0.93620598],
#        [0.6018507 , 0.64183932],
#        [0.69139352, 0.64892026],
#        [0.26504619, 0.2035159 ],
#        [0.8960313 , 0.64966373],
#        [0.39384426, 0.44534477],
#        [0.11300258, 0.17097449],
#        [0.59576468, 0.33979576],
#        [0.93912757, 0.81636027],
#        [0.7796957 , 0.12282699],
#        [0.00616326, 0.52149047],
#        [0.48688021, 0.59851393],
#        [0.74704888, 0.81561945],
#        [0.65038445, 0.96945526],
#        [0.16998953, 0.43864549],
#        [0.40574678, 0.91158347],
# ...

# %% [markdown]
# # Brutalna siła

# %%
bruteForce.bf(n, cities)

# %% [markdown]
# # Algorytm najbliższego sąsiada

# %%
nearestNeighbors.greedy_algorthm(n, cities)

# %% [markdown]
# # Ant Colony Optimization

# %%
AntColonyOptimization.aco(n, cities)
# Out:
# 5.513 [39, 11, 31, 2, 37, 21, 38, 9, 8, 7, 15, 33, 18, 26, 1, 22, 32, 29, 28, 27, 30, 36, 4, 5, 17, 34, 19, 23, 13, 14, 24, 10, 25, 6, 12, 0, 20, 35, 3, 16, 39]

# %% [markdown]
# # Algorytm genetyczny

# %%
npop=5 # liczba osobników populacji
start=cities[0]
cities_GA = cities
cities_GA = np.delete(cities_GA, 0, 0)

# %%
GeneticAlgorithm.GA(n, npop, start, cities_GA)
